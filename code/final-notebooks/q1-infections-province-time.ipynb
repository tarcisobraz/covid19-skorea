# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Question:

# %% [markdown]
# ### How did the disease spread within the provinces over time? (Descriptive / Exploratory)

# %% [markdown]
# ## Reading Data - Infections over Time per Province

# %% [markdown]
# #### [Dataset Description](https://www.kaggle.com/kimjihoo/ds4c-what-is-this-dataset-detailed-description)

# %% [markdown]
# ##### Quick Data Exploration

# %%
infections_prov_time = pd.read_csv('../../data/TimeProvince.csv')

# %%
infections_prov_time.head()
# Out:
#          date  time province  confirmed  released  deceased
# 0  2020-01-20    16    Seoul          0         0         0
# 1  2020-01-20    16    Busan          0         0         0
# 2  2020-01-20    16    Daegu          0         0         0
# 3  2020-01-20    16  Incheon          1         0         0
# 4  2020-01-20    16  Gwangju          0         0         0

# %%
infections_prov_time.describe()
# Out:
#               time    confirmed     released     deceased
# count  1564.000000  1564.000000  1564.000000  1564.000000
# mean      7.304348   290.842711   126.927749     4.335038
# std       7.972246  1112.384174   642.360989    19.190269
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000    14.000000     2.000000     0.000000
# 75%      16.000000    72.250000    21.000000     0.000000
# max      16.000000  6833.000000  5769.000000   163.000000

# %%
infections_prov_time[infections_prov_time['province'] == 'Seoul'].sort_values(['province','date']).head(20)
# Out:
#            date  time province  confirmed  released  deceased
# 0    2020-01-20    16    Seoul          0         0         0
# 17   2020-01-21    16    Seoul          0         0         0
# 34   2020-01-22    16    Seoul          0         0         0
# 51   2020-01-23    16    Seoul          0         0         0
# 68   2020-01-24    16    Seoul          0         0         0
# 85   2020-01-25    16    Seoul          0         0         0
# 102  2020-01-26    16    Seoul          0         0         0
# 119  2020-01-27    16    Seoul          1         0         0
# 136  2020-01-28    16    Seoul          1         0         0
# 153  2020-01-29    16    Seoul          1         0         0
# 170  2020-01-30    16    Seoul          3         0         0
# 187  2020-01-31    16    Seoul          4         0         0
# 204  2020-02-01    16    Seoul          4         0         0
# 221  2020-02-02    16    Seoul          5         0         0
# 238  2020-02-03    16    Seoul          5         0         0
# 255  2020-02-04    16    Seoul          5         0         0
# 272  2020-02-05    16    Seoul          5         1         0
# 289  2020-02-06    16    Seoul         10         1         0
# 306  2020-02-07    16    Seoul         11         1         0
# 323  2020-02-08    16    Seoul         11         1         0

# %% [markdown]
# #### Munging data to compute the number of infections per day since 1st infection day

# %%
infections_prov_time_clean = infections_prov_time.rename(index=str, columns={'confirmed':'accum_confirmed',
                                                                             'released':'accum_released',
                                                                             'deceased':'accum_deceased'})

infections_prov_time_clean
# Out:
#             date  time          province  accum_confirmed  accum_released  \
# 0     2020-01-20    16             Seoul                0               0
# 1     2020-01-20    16             Busan                0               0
# 2     2020-01-20    16             Daegu                0               0
# 3     2020-01-20    16           Incheon                1               0
# 4     2020-01-20    16           Gwangju                0               0
# ...          ...   ...               ...              ...             ...
# 1559  2020-04-20     0      Jeollabuk-do               17               9
# 1560  2020-04-20     0      Jeollanam-do               15               8
# 1561  2020-04-20     0  Gyeongsangbuk-do             1361            1064
# 1562  2020-04-20     0  Gyeongsangnam-do              116              87
# 1563  2020-04-20     0           Jeju-do               13               6
#
#       accum_deceased
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1559               0
# 1560               0
# 1561              51
# 1562               0
# 1563               0
#
# [1564 rows x 6 columns]

# %%
day_one_per_province = infections_prov_time_clean[infections_prov_time_clean['accum_confirmed'] > 0] \
                                                  .sort_values(['province','date']) \
                                                  .groupby(['province']) \
                                                  .head(1) \
                                                  .reset_index() \
                                                  .filter(['province','date']) \
                                                  .assign(days_since_day1 = 1)

day_one_per_province
# Out:
#              province        date  days_since_day1
# 0               Busan  2020-02-20                1
# 1   Chungcheongbuk-do  2020-02-21                1
# 2   Chungcheongnam-do  2020-02-21                1
# 3               Daegu  2020-02-18                1
# 4             Daejeon  2020-02-22                1
# 5          Gangwon-do  2020-02-22                1
# 6             Gwangju  2020-02-04                1
# 7         Gyeonggi-do  2020-01-24                1
# 8    Gyeongsangbuk-do  2020-02-19                1
# 9    Gyeongsangnam-do  2020-02-19                1
# 10            Incheon  2020-01-20                1
# 11            Jeju-do  2020-02-21                1
# 12       Jeollabuk-do  2020-01-31                1
# 13       Jeollanam-do  2020-02-22                1
# 14             Sejong  2020-02-22                1
# 15              Seoul  2020-01-27                1
# 16              Ulsan  2020-02-22                1

# %%
infections_since_day1 = pd.merge(infections_prov_time_clean,day_one_per_province, how='left')
infections_since_day1['after_day1'] = infections_since_day1.groupby(['province']).days_since_day1.transform(lambda x : x.ffill()).fillna(0)
infections_since_day1 = infections_since_day1[infections_since_day1['after_day1'] == 1]
infections_since_day1['days_since_day1'] = infections_since_day1.groupby(['province']).after_day1.transform(lambda x : x.cumsum()).fillna(0)
infections_since_day1 = infections_since_day1.drop(columns=['after_day1'], axis=1)
infections_since_day1
# Out:
#             date  time          province  accum_confirmed  accum_released  \
# 3     2020-01-20    16           Incheon                1               0
# 20    2020-01-21    16           Incheon                1               0
# 37    2020-01-22    16           Incheon                1               0
# 54    2020-01-23    16           Incheon                1               0
# 71    2020-01-24    16           Incheon                1               0
# ...          ...   ...               ...              ...             ...
# 1559  2020-04-20     0      Jeollabuk-do               17               9
# 1560  2020-04-20     0      Jeollanam-do               15               8
# 1561  2020-04-20     0  Gyeongsangbuk-do             1361            1064
# 1562  2020-04-20     0  Gyeongsangnam-do              116              87
# 1563  2020-04-20     0           Jeju-do               13               6
#
#       accum_deceased  days_since_day1
# 3                  0              1.0
# 20                 0              2.0
# 37                 0              3.0
# 54                 0              4.0
# 71                 0              5.0
# ...              ...              ...
# 1559               0             81.0
# 1560               0             59.0
# 1561              51             62.0
# 1562               0             62.0
# 1563               0             60.0
#
# [1146 rows x 7 columns]

# %%
infections_since_day1.sort_values(['days_since_day1','province'])
# Out:
#             date  time           province  accum_confirmed  accum_released  \
# 528   2020-02-20    16              Busan                8               0
# 554   2020-02-21    16  Chungcheongbuk-do                1               0
# 555   2020-02-21    16  Chungcheongnam-do                1               0
# 495   2020-02-18    16              Daegu                1               0
# 566   2020-02-22    16            Daejeon                2               0
# ...          ...   ...                ...              ...             ...
# 1482  2020-04-16     0            Incheon               88              51
# 1499  2020-04-17     0            Incheon               89              51
# 1516  2020-04-18     0            Incheon               90              55
# 1533  2020-04-19     0            Incheon               91              55
# 1550  2020-04-20     0            Incheon               92              56
#
#       accum_deceased  days_since_day1
# 528                0              1.0
# 554                0              1.0
# 555                0              1.0
# 495                0              1.0
# 566                0              1.0
# ...              ...              ...
# 1482               0             88.0
# 1499               0             89.0
# 1516               0             90.0
# 1533               0             91.0
# 1550               0             92.0
#
# [1146 rows x 7 columns]

# %% [markdown]
# #### Adding population density data to compute proportional rates

# %%
province_data = {
    'province': ['Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do', 'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do', 
    'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Busan', 'Daegu', 'Daejeon', 'Gwangju', 'Incheon', 'Ulsan', 'Seoul', 'Jeju-do', 'Sejong'],
    'population': [12479061, 1518040, 1589377, 2107802, 1834114, 1799044, 2680294, 3334524, 3448737, 2466052, 1538394, 1502881, 2890451, 1166615, 9904312, 605619, 204088],
    'area': [10183.5, 16827.1, 7407.3, 8226.1, 8069.1, 12318.8, 19031.4, 10539.6, 769.6, 883.6, 539.3, 501.2, 1062.6, 1060.8, 605.2, 1849.1, 464.9]
}

provinces = pd.DataFrame(data = province_data, columns = ['province', 'population', 'area'])
provinces['pop_density'] = provinces['population'] / provinces['area']

# %%
provinces
# Out:
#              province  population     area   pop_density
# 0         Gyeonggi-do    12479061  10183.5   1225.419649
# 1          Gangwon-do     1518040  16827.1     90.214000
# 2   Chungcheongbuk-do     1589377   7407.3    214.569006
# 3   Chungcheongnam-do     2107802   8226.1    256.233452
# 4        Jeollabuk-do     1834114   8069.1    227.300938
# 5        Jeollanam-do     1799044  12318.8    146.040523
# 6    Gyeongsangbuk-do     2680294  19031.4    140.835356
# 7    Gyeongsangnam-do     3334524  10539.6    316.380508
# 8               Busan     3448737    769.6   4481.207121
# 9               Daegu     2466052    883.6   2790.914441
# 10            Daejeon     1538394    539.3   2852.575561
# 11            Gwangju     1502881    501.2   2998.565443
# 12            Incheon     2890451   1062.6   2720.168455
# 13              Ulsan     1166615   1060.8   1099.750189
# 14              Seoul     9904312    605.2  16365.353602
# 15            Jeju-do      605619   1849.1    327.520956
# 16             Sejong      204088    464.9    438.993332

# %%
infections_since_day1_full = pd.merge(infections_since_day1, provinces, how='left')
infections_since_day1_full['accum_confirmed_perc_total_pop'] = 100 * (infections_since_day1_full['accum_confirmed'] / infections_since_day1_full['population'])
infections_since_day1_full['accum_confirmed_per_million_people'] = (infections_since_day1_full['accum_confirmed'] / (infections_since_day1_full['population']/10**6))
infections_since_day1_full
# Out:
#             date  time          province  accum_confirmed  accum_released  \
# 0     2020-01-20    16           Incheon                1               0
# 1     2020-01-21    16           Incheon                1               0
# 2     2020-01-22    16           Incheon                1               0
# 3     2020-01-23    16           Incheon                1               0
# 4     2020-01-24    16           Incheon                1               0
# ...          ...   ...               ...              ...             ...
# 1141  2020-04-20     0      Jeollabuk-do               17               9
# 1142  2020-04-20     0      Jeollanam-do               15               8
# 1143  2020-04-20     0  Gyeongsangbuk-do             1361            1064
# 1144  2020-04-20     0  Gyeongsangnam-do              116              87
# 1145  2020-04-20     0           Jeju-do               13               6
#
#       accum_deceased  days_since_day1  population     area  pop_density  \
# 0                  0              1.0     2890451   1062.6  2720.168455
# 1                  0              2.0     2890451   1062.6  2720.168455
# 2                  0              3.0     2890451   1062.6  2720.168455
# 3                  0              4.0     2890451   1062.6  2720.168455
# 4                  0              5.0     2890451   1062.6  2720.168455
# ...              ...              ...         ...      ...          ...
# 1141               0             81.0     1834114   8069.1   227.300938
# 1142               0             59.0     1799044  12318.8   146.040523
# 1143              51             62.0     2680294  19031.4   140.835356
# 1144               0             62.0     3334524  10539.6   316.380508
# 1145               0             60.0      605619   1849.1   327.520956
#
#       accum_confirmed_perc_total_pop  accum_confirmed_per_million_people
# 0                           0.000035                            0.345967
# 1                           0.000035                            0.345967
# 2                           0.000035                            0.345967
# 3                           0.000035                            0.345967
# 4                           0.000035                            0.345967
# ...                              ...                                 ...
# 1141                        0.000927                            9.268780
# 1142                        0.000834                            8.337762
# 1143                        0.050778                          507.780117
# 1144                        0.003479                           34.787574
# 1145                        0.002147                           21.465641
#
# [1146 rows x 12 columns]

# %% [markdown]
# #### Finding the provinces with higher infection rate (actual numbers and proportional numbers)

# %%
total_per_province = infections_since_day1_full.sort_values(['province','date']).groupby('province').tail(1).reset_index()
total_per_province = total_per_province[['date','province','days_since_day1','population','pop_density','accum_confirmed','accum_confirmed_perc_total_pop','accum_confirmed_per_million_people']]
total_per_province
# Out:
#           date           province  days_since_day1  population   pop_density  \
# 0   2020-04-20              Busan             61.0     3448737   4481.207121
# 1   2020-04-20  Chungcheongbuk-do             60.0     1589377    214.569006
# 2   2020-04-20  Chungcheongnam-do             60.0     2107802    256.233452
# 3   2020-04-20              Daegu             63.0     2466052   2790.914441
# 4   2020-04-20            Daejeon             59.0     1538394   2852.575561
# 5   2020-04-20         Gangwon-do             59.0     1518040     90.214000
# 6   2020-04-20            Gwangju             77.0     1502881   2998.565443
# 7   2020-04-20        Gyeonggi-do             88.0    12479061   1225.419649
# 8   2020-04-20   Gyeongsangbuk-do             62.0     2680294    140.835356
# 9   2020-04-20   Gyeongsangnam-do             62.0     3334524    316.380508
# 10  2020-04-20            Incheon             92.0     2890451   2720.168455
# 11  2020-04-20            Jeju-do             60.0      605619    327.520956
# 12  2020-04-20       Jeollabuk-do             81.0     1834114    227.300938
# 13  2020-04-20       Jeollanam-do             59.0     1799044    146.040523
# 14  2020-04-20             Sejong             59.0      204088    438.993332
# 15  2020-04-20              Seoul             85.0     9904312  16365.353602
# 16  2020-04-20              Ulsan             59.0     1166615   1099.750189
#
#     accum_confirmed  accum_confirmed_perc_total_pop  \
# 0               132                        0.003827
# 1                45                        0.002831
# 2               141                        0.006689
# 3              6833                        0.277083
# 4                39                        0.002535
# 5                53                        0.003491
# 6                30                        0.001996
# 7               656                        0.005257
# 8              1361                        0.050778
# 9               116                        0.003479
# 10               92                        0.003183
# 11               13                        0.002147
# 12               17                        0.000927
# 13               15                        0.000834
# 14               46                        0.022539
# 15              624                        0.006300
# 16               43                        0.003686
#
#     accum_confirmed_per_million_people
# 0                            38.274882
# 1                            28.312980
# 2                            66.894329
# 3                          2770.825595
# 4                            25.351113
# 5                            34.913441
# 6                            19.961660
# 7                            52.568058
# 8                           507.780117
# 9                            34.787574
# 10                           31.828943
# 11                           21.465641
# 12                            9.268780
# 13                            8.337762
# 14                          225.392968
# 15                           63.002862
# 16                           36.858775

# %%
province_inf_rate_real_nos = total_per_province.sort_values('accum_confirmed', ascending=False)
province_inf_rate_real_nos
# Out:
#           date           province  days_since_day1  population   pop_density  \
# 3   2020-04-20              Daegu             63.0     2466052   2790.914441
# 8   2020-04-20   Gyeongsangbuk-do             62.0     2680294    140.835356
# 7   2020-04-20        Gyeonggi-do             88.0    12479061   1225.419649
# 15  2020-04-20              Seoul             85.0     9904312  16365.353602
# 2   2020-04-20  Chungcheongnam-do             60.0     2107802    256.233452
# 0   2020-04-20              Busan             61.0     3448737   4481.207121
# 9   2020-04-20   Gyeongsangnam-do             62.0     3334524    316.380508
# 10  2020-04-20            Incheon             92.0     2890451   2720.168455
# 5   2020-04-20         Gangwon-do             59.0     1518040     90.214000
# 14  2020-04-20             Sejong             59.0      204088    438.993332
# 1   2020-04-20  Chungcheongbuk-do             60.0     1589377    214.569006
# 16  2020-04-20              Ulsan             59.0     1166615   1099.750189
# 4   2020-04-20            Daejeon             59.0     1538394   2852.575561
# 6   2020-04-20            Gwangju             77.0     1502881   2998.565443
# 12  2020-04-20       Jeollabuk-do             81.0     1834114    227.300938
# 13  2020-04-20       Jeollanam-do             59.0     1799044    146.040523
# 11  2020-04-20            Jeju-do             60.0      605619    327.520956
#
#     accum_confirmed  accum_confirmed_perc_total_pop  \
# 3              6833                        0.277083
# 8              1361                        0.050778
# 7               656                        0.005257
# 15              624                        0.006300
# 2               141                        0.006689
# 0               132                        0.003827
# 9               116                        0.003479
# 10               92                        0.003183
# 5                53                        0.003491
# 14               46                        0.022539
# 1                45                        0.002831
# 16               43                        0.003686
# 4                39                        0.002535
# 6                30                        0.001996
# 12               17                        0.000927
# 13               15                        0.000834
# 11               13                        0.002147
#
#     accum_confirmed_per_million_people
# 3                          2770.825595
# 8                           507.780117
# 7                            52.568058
# 15                           63.002862
# 2                            66.894329
# 0                            38.274882
# 9                            34.787574
# 10                           31.828943
# 5                            34.913441
# 14                          225.392968
# 1                            28.312980
# 16                           36.858775
# 4                            25.351113
# 6                            19.961660
# 12                            9.268780
# 13                            8.337762
# 11                           21.465641

# %%
top_infected_provinces_real_nos = total_per_province.sort_values('accum_confirmed', ascending=False).head(5).province
provinces_palette = {'Daegu':'#9b59b6', 'Gyeongsangbuk-do':'#3498db', 'Gyeonggi-do':'#95a5a6','Seoul':'#e74c3c', 
                         'Chungcheongnam-do':'#34495e', 'Sejong':'#2ecc71'}

plt.figure(figsize=(10, 6))
sns.set_style('whitegrid')
p = sns.lineplot(x="days_since_day1",
                 y="accum_confirmed",
                 hue="province",
                 data=infections_since_day1_full[infections_since_day1_full.province.isin(
                     top_infected_provinces_real_nos)],
                 palette=provinces_palette);
p.axes.set_title('Infection Curve per Province since day 1', fontsize = 16, weight='bold');
p.set_xlabel('Days since day 1', fontsize = 10);
p.set_ylabel('Number of confirmed cases', fontsize = 10);

# %%
plt.figure(figsize=(10, 6))
sns.set_style('whitegrid')
p = sns.lineplot(x="days_since_day1",
                 y="accum_confirmed",
                 hue="province",
                 data=infections_since_day1_full[infections_since_day1_full.province.isin(
                     top_infected_provinces_real_nos)],
                 palette=provinces_palette);
p.set_yscale("log");
p.axes.set_title('Infection Curve per Province since day 1', fontsize = 16, weight='bold');
p.set_xlabel('Days since day 1', fontsize = 10);
p.set_ylabel('Number of confirmed cases - log scale', fontsize = 10);

# %%
top_infected_provinces_prop_nos = total_per_province.sort_values('accum_confirmed_perc_total_pop', ascending=False).head(5).province

plt.figure(figsize=(16, 6))
p = sns.lineplot(x="days_since_day1",
                 y="accum_confirmed_perc_total_pop",
                 hue="province",
                 data=infections_since_day1_full[infections_since_day1_full.province.isin(
                     top_infected_provinces_prop_nos)],
                 palette=provinces_palette);
#p.set_yscale("log");
p.axes.set_title('Proportional Infection Curve per Province since day 1', fontsize = 16, weight='bold');
p.set_xlabel('Days since day 1', fontsize = 10);
p.set_ylabel('Number of confirmed cases / Total Population (%) - log scale', fontsize = 10);

# %%
total_per_province.sort_values('accum_confirmed_per_million_people', ascending=False).head(5)
# Out:
#           date           province  days_since_day1  population   pop_density  \
# 3   2020-04-20              Daegu             63.0     2466052   2790.914441
# 8   2020-04-20   Gyeongsangbuk-do             62.0     2680294    140.835356
# 14  2020-04-20             Sejong             59.0      204088    438.993332
# 2   2020-04-20  Chungcheongnam-do             60.0     2107802    256.233452
# 15  2020-04-20              Seoul             85.0     9904312  16365.353602
#
#     accum_confirmed  accum_confirmed_perc_total_pop  \
# 3              6833                        0.277083
# 8              1361                        0.050778
# 14               46                        0.022539
# 2               141                        0.006689
# 15              624                        0.006300
#
#     accum_confirmed_per_million_people
# 3                          2770.825595
# 8                           507.780117
# 14                          225.392968
# 2                            66.894329
# 15                           63.002862

# %%
top_infected_provinces_perm_nos = total_per_province.sort_values('accum_confirmed_per_million_people', ascending=False).head(5).province

f = plt.figure(figsize=(10, 6))
p = sns.lineplot(x="days_since_day1",
                 y="accum_confirmed_per_million_people",
                 hue="province",
                 data=infections_since_day1_full[infections_since_day1_full.province.isin(
                     top_infected_provinces_perm_nos)],
                 palette=provinces_palette);

p.axes.set_title('Proportional Infection Curve per Province since day 1 (real numbers)', fontsize = 16, weight='bold');
p.set_xlabel('Days since day 1', fontsize = 10);
p.set_ylabel('Number of confirmed cases per million people', fontsize = 10);

# %%
f.savefig("../../assets/q1-province-infections-over-time-real.png", bbox_inches='tight', dpi=600);

# %%
f2 = plt.figure(figsize=(10, 6))
p = sns.lineplot(x="days_since_day1",
                 y="accum_confirmed_per_million_people",
                 hue="province",
                 data=infections_since_day1_full[infections_since_day1_full.province.isin(
                     top_infected_provinces_perm_nos)],
                 palette=provinces_palette);
p.set_yscale("log");
p.axes.set_title('Proportional Infection Curve per Province since day 1 (log scale)', fontsize = 16, weight='bold');
p.set_xlabel('Days since day 1', fontsize = 10);
p.set_ylabel('Number of confirmed cases per million people - log scale', fontsize = 10);

# %%
f2.savefig("../../assets/q1-province-infections-over-time-log.png", bbox_inches='tight', dpi=600);
