# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Question:

# %% [markdown]
# ### What characteristics are good predictors of the patient status? (Predictive / Inference)

# %% [markdown]
# ## Reading Data - Patient Info

# %% [markdown]
# #### [Dataset Description](https://www.kaggle.com/kimjihoo/ds4c-what-is-this-dataset-detailed-description)

# %%
patient_info = pd.read_csv('../../data/PatientInfo.csv')

# %% [markdown]
# #### Taking a look at the data

# %%
patient_info.head(30)
# Out:
#     patient_id  global_num     sex  birth_year  age country province  \
# 0   1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1   1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2   1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3   1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4   1000000005         9.0  female      1992.0  20s   Korea    Seoul
# 5   1000000006        10.0  female      1966.0  50s   Korea    Seoul
# 6   1000000007        11.0    male      1995.0  20s   Korea    Seoul
# 7   1000000008        13.0    male      1992.0  20s   Korea    Seoul
# 8   1000000009        19.0    male      1983.0  30s   Korea    Seoul
# 9   1000000010        21.0  female      1960.0  60s   Korea    Seoul
# 10  1000000011        23.0  female      1962.0  50s   China    Seoul
# 11  1000000012        24.0    male      1992.0  20s   Korea    Seoul
# 12  1000000013        29.0    male      1938.0  80s   Korea    Seoul
# 13  1000000014        30.0  female      1952.0  60s   Korea    Seoul
# 14  1000000015        40.0    male      1943.0  70s   Korea    Seoul
# 15  1000000016        56.0    male      1945.0  70s   Korea    Seoul
# 16  1000000017        83.0    male      1944.0  70s   Korea    Seoul
# 17  1000000018       111.0    male      2000.0  20s   Korea    Seoul
# 18  1000000019       112.0  female      1941.0  70s   Korea    Seoul
# 19  1000000020       121.0  female      1944.0  70s   Korea    Seoul
# 20  1000000021       136.0    male      1936.0  80s   Korea    Seoul
# 21  1000000022       161.0    male      1985.0  30s   Korea    Seoul
# 22  1000000023       188.0    male      1961.0  50s   Korea    Seoul
# 23  1000000024       348.0    male      1980.0  40s   Korea    Seoul
# 24  1000000025       365.0    male      1958.0  60s   Korea    Seoul
# 25  1000000026       420.0    male      1986.0  30s   Korea    Seoul
# 26  1000000027       593.0    male      1968.0  50s   Korea    Seoul
# 27  1000000028       627.0  female      1950.0  70s   Korea    Seoul
# 28  1000000029       754.0  female      1995.0  20s   Korea    Seoul
# 29  1000000030       755.0    male      1954.0  60s   China    Seoul
#
#             city disease                 infection_case  infection_order  \
# 0     Gangseo-gu     NaN                overseas inflow              1.0
# 1    Jungnang-gu     NaN                overseas inflow              1.0
# 2      Jongno-gu     NaN           contact with patient              2.0
# 3        Mapo-gu     NaN                overseas inflow              1.0
# 4    Seongbuk-gu     NaN           contact with patient              2.0
# 5      Jongno-gu     NaN           contact with patient              3.0
# 6      Jongno-gu     NaN           contact with patient              3.0
# 7            etc     NaN                overseas inflow              1.0
# 8      Songpa-gu     NaN                overseas inflow              2.0
# 9    Seongbuk-gu     NaN           contact with patient              3.0
# 10  Seodaemun-gu     NaN                overseas inflow              1.0
# 11           etc     NaN                overseas inflow              1.0
# 12     Jongno-gu     NaN           contact with patient              4.0
# 13     Jongno-gu     NaN           contact with patient              5.0
# 14  Seongdong-gu     NaN               Seongdong-gu APT              NaN
# 15     Jongno-gu     NaN           contact with patient              4.0
# 16     Jongno-gu     NaN           contact with patient              3.0
# 17           etc     NaN                            etc              NaN
# 18     Jongno-gu     NaN           contact with patient              5.0
# 19  Seongdong-gu     NaN               Seongdong-gu APT              NaN
# 20     Jongno-gu     NaN           contact with patient              5.0
# 21  Seodaemun-gu     NaN  Eunpyeong St. Mary's Hospital              NaN
# 22     Seocho-gu     NaN             Shincheonji Church              NaN
# 23       Guro-gu     NaN           contact with patient              NaN
# 24   Gangdong-gu     NaN  Eunpyeong St. Mary's Hospital              NaN
# 25     Seocho-gu     NaN                            etc              NaN
# 26    Gangseo-gu     NaN                overseas inflow              NaN
# 27     Jongno-gu     NaN  Eunpyeong St. Mary's Hospital              NaN
# 28     Jongno-gu     NaN  Eunpyeong St. Mary's Hospital              NaN
# 29   Gangdong-gu     NaN  Eunpyeong St. Mary's Hospital              NaN
#
#      infected_by  contact_number symptom_onset_date confirmed_date  \
# 0            NaN            75.0         2020-01-22     2020-01-23
# 1            NaN            31.0                NaN     2020-01-30
# 2   2.002000e+09            17.0                NaN     2020-01-30
# 3            NaN             9.0         2020-01-26     2020-01-30
# 4   1.000000e+09             2.0                NaN     2020-01-31
# 5   1.000000e+09            43.0                NaN     2020-01-31
# 6   1.000000e+09             0.0                NaN     2020-01-31
# 7            NaN             0.0                NaN     2020-02-02
# 8            NaN            68.0                NaN     2020-02-05
# 9   1.000000e+09             6.0                NaN     2020-02-05
# 10           NaN            23.0                NaN     2020-02-06
# 11           NaN             0.0                NaN     2020-02-07
# 12  1.000000e+09           117.0                NaN     2020-02-16
# 13  1.000000e+09            27.0         2020-02-06     2020-02-16
# 14           NaN             8.0         2020-02-11     2020-02-19
# 15  1.000000e+09             NaN                NaN     2020-02-19
# 16  1.000000e+09             NaN                NaN     2020-02-20
# 17           NaN             NaN                NaN     2020-02-20
# 18  1.000000e+09             NaN                NaN     2020-02-20
# 19  1.000000e+09             NaN                NaN     2020-02-20
# 20  1.000000e+09             NaN                NaN     2020-02-20
# 21           NaN             NaN                NaN     2020-02-21
# 22           NaN             NaN                NaN     2020-02-21
# 23           NaN             NaN                NaN     2020-02-22
# 24  1.000000e+09             NaN                NaN     2020-02-22
# 25           NaN             NaN         2020-02-21     2020-02-22
# 26           NaN             NaN                NaN     2020-02-23
# 27           NaN             NaN                NaN     2020-02-23
# 28  1.000000e+09             NaN         2020-02-11     2020-02-26
# 29           NaN             NaN                NaN     2020-02-23
#
#    released_date deceased_date     state
# 0     2020-02-05           NaN  released
# 1     2020-03-02           NaN  released
# 2     2020-02-19           NaN  released
# 3     2020-02-15           NaN  released
# 4     2020-02-24           NaN  released
# 5     2020-02-19           NaN  released
# 6     2020-02-10           NaN  released
# 7     2020-02-24           NaN  released
# 8     2020-02-21           NaN  released
# 9     2020-02-29           NaN  released
# 10    2020-02-29           NaN  released
# 11    2020-02-27           NaN  released
# 12           NaN           NaN  released
# 13    2020-03-12           NaN  released
# 14           NaN           NaN  isolated
# 15    2020-03-11           NaN  released
# 16    2020-03-01           NaN  released
# 17           NaN           NaN  released
# 18    2020-03-08           NaN  released
# 19           NaN           NaN  released
# 20    2020-03-08           NaN  released
# 21           NaN           NaN  isolated
# 22           NaN           NaN  isolated
# 23    2020-03-14           NaN  released
# 24           NaN           NaN  released
# 25    2020-03-11           NaN  released
# 26    2020-03-04           NaN  released
# 27    2020-03-11           NaN  released
# 28    2020-03-11           NaN  released
# 29           NaN           NaN  released

# %%
patient_info.shape
# Out:
# (3326, 18)

# %%
patient_info.describe()
# Out:
#          patient_id    global_num   birth_year  infection_order   infected_by  \
# count  3.326000e+03   2237.000000  2889.000000        31.000000  8.060000e+02
# mean   3.514908e+09   6669.169423  1974.956732         2.387097  2.671714e+09
# std    2.209142e+09   3321.396732    20.275471         1.453213  1.740450e+09
# min    1.000000e+09      1.000000  1916.000000         1.000000  1.000000e+09
# 25%    1.300000e+09   4172.000000  1961.000000         1.000000  1.200000e+09
# 50%    2.000001e+09   7855.000000  1975.000000         2.000000  2.000000e+09
# 75%    6.001001e+09   9433.000000  1993.000000         3.000000  4.100000e+09
# max    7.000000e+09  10660.000000  2020.000000         6.000000  7.000000e+09
#
#        contact_number
# count      614.000000
# mean        18.710098
# std         75.352899
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%         14.000000
# max       1160.000000

# %%
patient_info.describe(include=['object'])
# Out:
#            sex   age country          province          city disease  \
# count     3260  3252    3326              3326          3247      18
# unique       2    11      11                17           151       1
# top     female   20s   Korea  Gyeongsangbuk-do  Gyeongsan-si    True
# freq      1831   790    3300              1223           631      18
#
#               infection_case symptom_onset_date confirmed_date released_date  \
# count                   2559                471           3323          1218
# unique                    23                 69             77            66
# top     contact with patient         2020-02-27     2020-03-05    2020-03-20
# freq                     949                 29            145            69
#
#        deceased_date     state
# count             60      3326
# unique            33         3
# top       2020-02-23  released
# freq               4      1637

# %% [markdown]
# #### Checking for missing data

# %%
patient_info.apply(lambda x: x.isnull().mean(), axis=0).sort_values(ascending=False)
# Out:
# disease               0.994588
# infection_order       0.990679
# deceased_date         0.981960
# symptom_onset_date    0.858388
# contact_number        0.815394
# infected_by           0.757667
# released_date         0.633794
# global_num            0.327420
# infection_case        0.230607
# birth_year            0.131389
# city                  0.023752
# age                   0.022249
# sex                   0.019844
# confirmed_date        0.000902
# state                 0.000000
# country               0.000000
# province              0.000000
# patient_id            0.000000
# dtype: float64

# %% [markdown]
# ### Model Design

# %% [markdown]
# #### Model V. 0.1 - y ~ X:
# - y = state
# - X = f ( province, sex, age, infection_case )

# %%
model_v01_data = patient_info[['province', 'sex', 'age', 'infection_case', 'state']]

# %%
print(model_v01_data.shape)
model_v01_data.head()
# Out:
# (3326, 5)
#   province     sex  age        infection_case     state
# 0    Seoul    male  50s       overseas inflow  released
# 1    Seoul    male  30s       overseas inflow  released
# 2    Seoul    male  50s  contact with patient  released
# 3    Seoul    male  20s       overseas inflow  released
# 4    Seoul  female  20s  contact with patient  released

# %% [markdown]
# #### Deciding what to do for each column (missing data, value encoding, data treatment)

# %% [markdown]
# ##### infection_case

# %%
patients_infection_case = patient_info[~patient_info['infection_case'].isnull()]
print(patients_infection_case.shape)
patients_infection_case.sort_values(['confirmed_date'])
# Out:
# (2559, 18)
#       patient_id  global_num     sex  birth_year  age country  \
# 846   1400000001         1.0  female      1985.0  30s   China
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1065  2000000001         3.0    male      1966.0  50s   Korea
# 1066  2000000002         4.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1720  2000000656         NaN    male      1964.0  50s   Korea
# 937   1400000092         NaN    male      1992.0  20s   Korea
# 2923  6011000051         NaN  female      1980.0  40s   Korea
# 2924  6011000052         NaN  female      2011.0   0s   Korea
# 2925  6011000053         NaN  female      2001.0  10s   Korea
#
#               province           city disease        infection_case  \
# 846            Incheon            etc     NaN       overseas inflow
# 0                Seoul     Gangseo-gu     NaN       overseas inflow
# 1065       Gyeonggi-do      Goyang-si     NaN       overseas inflow
# 1066       Gyeonggi-do  Pyeongtaek-si     NaN       overseas inflow
# 1                Seoul    Jungnang-gu     NaN       overseas inflow
# ...                ...            ...     ...                   ...
# 1720       Gyeonggi-do   Namyangju-si     NaN  contact with patient
# 937            Incheon     Gyeyang-gu     NaN       overseas inflow
# 2923  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2924  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2925  Gyeongsangbuk-do      Andong-si     NaN                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 846               NaN           NaN             NaN         2020-01-19
# 0                 1.0           NaN            75.0         2020-01-22
# 1065              1.0           NaN            16.0                NaN
# 1066              1.0           NaN            95.0                NaN
# 1                 1.0           NaN            31.0                NaN
# ...               ...           ...             ...                ...
# 1720              NaN  2.000001e+09             NaN                NaN
# 937               NaN           NaN             NaN                NaN
# 2923              NaN           NaN             NaN                NaN
# 2924              NaN           NaN             NaN                NaN
# 2925              NaN           NaN             NaN         2020-04-15
#
#      confirmed_date released_date deceased_date     state
# 846      2020-01-20    2020-02-06           NaN  released
# 0        2020-01-23    2020-02-05           NaN  released
# 1065     2020-01-26    2020-02-12           NaN  released
# 1066     2020-01-27    2020-02-09           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# ...             ...           ...           ...       ...
# 1720     2020-04-19           NaN           NaN  isolated
# 937      2020-04-19           NaN           NaN  isolated
# 2923            NaN           NaN           NaN  isolated
# 2924            NaN           NaN           NaN  isolated
# 2925            NaN           NaN           NaN  isolated
#
# [2559 rows x 18 columns]

# %%
patients_infection_case.state.value_counts()
# Out:
# isolated    1437
# released    1094
# deceased      28
# Name: state, dtype: int64

# %%
patients_infection_case.infection_case.value_counts()
# Out:
# contact with patient                     949
# etc                                      567
# overseas inflow                          567
# Guro-gu Call Center                      112
# Shincheonji Church                       107
# Onchun Church                             33
# Bonghwa Pureun Nursing Home               31
# gym facility in Cheonan                   30
# Ministry of Oceans and Fisheries          28
# Cheongdo Daenam Hospital                  21
# Dongan Church                             17
# Eunpyeong St. Mary's Hospital             16
# Gyeongsan Seorin Nursing Home             15
# Seongdong-gu APT                          13
# Gyeongsan Jeil Silver Town                12
# Milal Shelter                             11
# Gyeongsan Cham Joeun Community Center     10
# Geochang Church                            6
# Changnyeong Coin Karaoke                   4
# gym facility in Sejong                     4
# Suyeong-gu Kindergarten                    3
# Pilgrimage to Israel                       2
# River of Grace Community Church            1
# Name: infection_case, dtype: int64

# %% [markdown]
# As we can see, this column has data which encompasses old and current dates, and comprises all possible patient states. There are many infection case levels which are not going to be individually relevant to the prediction model. Thus, we will keep only two of the original levels: Contact with Patient and Overseas Inflow, and label the rest as Other.As it is a categorical variable, we will create a dummy variable to hold its NA values.

# %%
def resume_infection_case_col(inf_case_value):
    if ((pd.isnull(inf_case_value)) or (inf_case_value in ['contact with patient','overseas inflow'])):
        return inf_case_value
    else:
        return 'other'
    
model_v01_data.loc[:,'infection_case'] = model_v01_data['infection_case'].apply(resume_infection_case_col)
# Out:
# /local/tarciso/anaconda3/envs/udacity-ds-p1/lib/python3.6/site-packages/pandas/core/indexing.py:1048: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
model_v01_data.head(20)
# Out:
#    province     sex  age        infection_case     state
# 0     Seoul    male  50s       overseas inflow  released
# 1     Seoul    male  30s       overseas inflow  released
# 2     Seoul    male  50s  contact with patient  released
# 3     Seoul    male  20s       overseas inflow  released
# 4     Seoul  female  20s  contact with patient  released
# 5     Seoul  female  50s  contact with patient  released
# 6     Seoul    male  20s  contact with patient  released
# 7     Seoul    male  20s       overseas inflow  released
# 8     Seoul    male  30s       overseas inflow  released
# 9     Seoul  female  60s  contact with patient  released
# 10    Seoul  female  50s       overseas inflow  released
# 11    Seoul    male  20s       overseas inflow  released
# 12    Seoul    male  80s  contact with patient  released
# 13    Seoul  female  60s  contact with patient  released
# 14    Seoul    male  70s                 other  isolated
# 15    Seoul    male  70s  contact with patient  released
# 16    Seoul    male  70s  contact with patient  released
# 17    Seoul    male  20s                 other  released
# 18    Seoul  female  70s  contact with patient  released
# 19    Seoul  female  70s                 other  released

# %%
model_v01_data = pd.get_dummies(data = model_v01_data, prefix = 'infection_case', prefix_sep = ':', columns = ['infection_case'], drop_first = False, dummy_na = True)

# %%
model_v01_data.head()
# Out:
#   province     sex  age     state  infection_case:contact with patient  \
# 0    Seoul    male  50s  released                                    0
# 1    Seoul    male  30s  released                                    0
# 2    Seoul    male  50s  released                                    1
# 3    Seoul    male  20s  released                                    0
# 4    Seoul  female  20s  released                                    1
#
#    infection_case:other  infection_case:overseas inflow  infection_case:nan
# 0                     0                               1                   0
# 1                     0                               1                   0
# 2                     0                               0                   0
# 3                     0                               1                   0
# 4                     0                               0                   0

# %% [markdown]
# ##### age

# %%
patients_age = patient_info[~patient_info['age'].isnull()]
print(patients_age.shape)
patients_age.sort_values(['confirmed_date'])
# Out:
# (3252, 18)
#       patient_id  global_num     sex  birth_year  age country  \
# 846   1400000001         1.0  female      1985.0  30s   China
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1065  2000000001         3.0    male      1966.0  50s   Korea
# 1066  2000000002         4.0    male      1964.0  50s   Korea
# 3     1000000004         7.0    male      1991.0  20s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1719  2000000655         NaN  female      1998.0  20s   Korea
# 937   1400000092         NaN    male      1992.0  20s   Korea
# 2923  6011000051         NaN  female      1980.0  40s   Korea
# 2924  6011000052         NaN  female      2011.0   0s   Korea
# 2925  6011000053         NaN  female      2001.0  10s   Korea
#
#               province           city disease   infection_case  \
# 846            Incheon            etc     NaN  overseas inflow
# 0                Seoul     Gangseo-gu     NaN  overseas inflow
# 1065       Gyeonggi-do      Goyang-si     NaN  overseas inflow
# 1066       Gyeonggi-do  Pyeongtaek-si     NaN  overseas inflow
# 3                Seoul        Mapo-gu     NaN  overseas inflow
# ...                ...            ...     ...              ...
# 1719       Gyeonggi-do      Yongin-si     NaN  overseas inflow
# 937            Incheon     Gyeyang-gu     NaN  overseas inflow
# 2923  Gyeongsangbuk-do      Andong-si     NaN              etc
# 2924  Gyeongsangbuk-do      Andong-si     NaN              etc
# 2925  Gyeongsangbuk-do      Andong-si     NaN              etc
#
#       infection_order  infected_by  contact_number symptom_onset_date  \
# 846               NaN          NaN             NaN         2020-01-19
# 0                 1.0          NaN            75.0         2020-01-22
# 1065              1.0          NaN            16.0                NaN
# 1066              1.0          NaN            95.0                NaN
# 3                 1.0          NaN             9.0         2020-01-26
# ...               ...          ...             ...                ...
# 1719              NaN          NaN             NaN                NaN
# 937               NaN          NaN             NaN                NaN
# 2923              NaN          NaN             NaN                NaN
# 2924              NaN          NaN             NaN                NaN
# 2925              NaN          NaN             NaN         2020-04-15
#
#      confirmed_date released_date deceased_date     state
# 846      2020-01-20    2020-02-06           NaN  released
# 0        2020-01-23    2020-02-05           NaN  released
# 1065     2020-01-26    2020-02-12           NaN  released
# 1066     2020-01-27    2020-02-09           NaN  released
# 3        2020-01-30    2020-02-15           NaN  released
# ...             ...           ...           ...       ...
# 1719     2020-04-19           NaN           NaN  isolated
# 937      2020-04-19           NaN           NaN  isolated
# 2923            NaN           NaN           NaN  isolated
# 2924            NaN           NaN           NaN  isolated
# 2925            NaN           NaN           NaN  isolated
#
# [3252 rows x 18 columns]

# %%
patient_info[patient_info['age'].isnull() & (~patient_info['birth_year'].isnull())]
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, symptom_onset_date, confirmed_date, released_date, deceased_date, state]
# Index: []

# %%
patients_age.state.value_counts()
# Out:
# released    1627
# isolated    1558
# deceased      67
# Name: state, dtype: int64

# %%
patients_age.age.value_counts()
# Out:
# 20s     790
# 50s     589
# 40s     453
# 30s     425
# 60s     398
# 70s     197
# 80s     155
# 10s     146
# 0s       53
# 90s      45
# 100s      1
# Name: age, dtype: int64

# %% [markdown]
# As we can see, this column has data which encompasses old and current dates, and comprises all possible patient states. As it is in essence a numeric variable, we will turn it into one, and will fill in its missing values with the mean.

# %%
model_v01_data.loc[:,'age'] = model_v01_data.age.str.replace('s','').astype('float')
model_v01_data.loc[:,'age'] = model_v01_data.age.fillna(model_v01_data.age.mean())

# %%
model_v01_data
# Out:
#      province     sex   age     state  infection_case:contact with patient  \
# 0       Seoul    male  50.0  released                                    0
# 1       Seoul    male  30.0  released                                    0
# 2       Seoul    male  50.0  released                                    1
# 3       Seoul    male  20.0  released                                    0
# 4       Seoul  female  20.0  released                                    1
# ...       ...     ...   ...       ...                                  ...
# 3321  Jeju-do  female  20.0  isolated                                    0
# 3322  Jeju-do  female  20.0  isolated                                    0
# 3323  Jeju-do    male  30.0  isolated                                    1
# 3324  Jeju-do  female  20.0  isolated                                    0
# 3325  Jeju-do  female  10.0  isolated                                    0
#
#       infection_case:other  infection_case:overseas inflow  infection_case:nan
# 0                        0                               1                   0
# 1                        0                               1                   0
# 2                        0                               0                   0
# 3                        0                               1                   0
# 4                        0                               0                   0
# ...                    ...                             ...                 ...
# 3321                     0                               1                   0
# 3322                     0                               1                   0
# 3323                     0                               0                   0
# 3324                     0                               1                   0
# 3325                     0                               1                   0
#
# [3326 rows x 8 columns]

# %%
model_v01_data.age.mean()
# Out:
# 40.528905289052865

# %%
model_v01_data[model_v01_data['age'] == patient_info.age.str.replace('s','').astype(float).mean()]
# Out:
#               province     sex        age     state  \
# 563              Seoul     NaN  40.528905  released
# 564              Seoul     NaN  40.528905  isolated
# 565              Seoul     NaN  40.528905  isolated
# 566              Seoul     NaN  40.528905  isolated
# 567              Seoul     NaN  40.528905  isolated
# ...                ...     ...        ...       ...
# 2926  Gyeongsangbuk-do  female  40.528905  released
# 2927  Gyeongsangbuk-do     NaN  40.528905  released
# 3228  Gyeongsangnam-do     NaN  40.528905  isolated
# 3229  Gyeongsangnam-do     NaN  40.528905  isolated
# 3230  Gyeongsangnam-do     NaN  40.528905  isolated
#
#       infection_case:contact with patient  infection_case:other  \
# 563                                     0                     1
# 564                                     0                     0
# 565                                     0                     0
# 566                                     0                     0
# 567                                     0                     0
# ...                                   ...                   ...
# 2926                                    0                     1
# 2927                                    0                     1
# 3228                                    0                     0
# 3229                                    0                     0
# 3230                                    0                     0
#
#       infection_case:overseas inflow  infection_case:nan
# 563                                0                   0
# 564                                1                   0
# 565                                1                   0
# 566                                1                   0
# 567                                1                   0
# ...                              ...                 ...
# 2926                               0                   0
# 2927                               0                   0
# 3228                               0                   1
# 3229                               0                   1
# 3230                               0                   1
#
# [74 rows x 8 columns]

# %% [markdown]
# ##### sex

# %%
patients_sex = patient_info[~patient_info['sex'].isnull()]
print(patients_sex.shape)
patients_sex.sort_values(['confirmed_date'])
# Out:
# (3260, 18)
#       patient_id  global_num     sex  birth_year  age country  \
# 846   1400000001         1.0  female      1985.0  30s   China
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1065  2000000001         3.0    male      1966.0  50s   Korea
# 1066  2000000002         4.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1720  2000000656         NaN    male      1964.0  50s   Korea
# 1719  2000000655         NaN  female      1998.0  20s   Korea
# 2923  6011000051         NaN  female      1980.0  40s   Korea
# 2924  6011000052         NaN  female      2011.0   0s   Korea
# 2925  6011000053         NaN  female      2001.0  10s   Korea
#
#               province           city disease        infection_case  \
# 846            Incheon            etc     NaN       overseas inflow
# 0                Seoul     Gangseo-gu     NaN       overseas inflow
# 1065       Gyeonggi-do      Goyang-si     NaN       overseas inflow
# 1066       Gyeonggi-do  Pyeongtaek-si     NaN       overseas inflow
# 1                Seoul    Jungnang-gu     NaN       overseas inflow
# ...                ...            ...     ...                   ...
# 1720       Gyeonggi-do   Namyangju-si     NaN  contact with patient
# 1719       Gyeonggi-do      Yongin-si     NaN       overseas inflow
# 2923  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2924  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2925  Gyeongsangbuk-do      Andong-si     NaN                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 846               NaN           NaN             NaN         2020-01-19
# 0                 1.0           NaN            75.0         2020-01-22
# 1065              1.0           NaN            16.0                NaN
# 1066              1.0           NaN            95.0                NaN
# 1                 1.0           NaN            31.0                NaN
# ...               ...           ...             ...                ...
# 1720              NaN  2.000001e+09             NaN                NaN
# 1719              NaN           NaN             NaN                NaN
# 2923              NaN           NaN             NaN                NaN
# 2924              NaN           NaN             NaN                NaN
# 2925              NaN           NaN             NaN         2020-04-15
#
#      confirmed_date released_date deceased_date     state
# 846      2020-01-20    2020-02-06           NaN  released
# 0        2020-01-23    2020-02-05           NaN  released
# 1065     2020-01-26    2020-02-12           NaN  released
# 1066     2020-01-27    2020-02-09           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# ...             ...           ...           ...       ...
# 1720     2020-04-19           NaN           NaN  isolated
# 1719     2020-04-19           NaN           NaN  isolated
# 2923            NaN           NaN           NaN  isolated
# 2924            NaN           NaN           NaN  isolated
# 2925            NaN           NaN           NaN  isolated
#
# [3260 rows x 18 columns]

# %%
patients_sex.state.value_counts()
# Out:
# released    1630
# isolated    1563
# deceased      67
# Name: state, dtype: int64

# %%
patients_sex.sex.value_counts()
# Out:
# female    1831
# male      1429
# Name: sex, dtype: int64

# %% [markdown]
# As we can see, this column has data which encompasses old and current dates, and comprises all possible patient states. As it is a categorical variable, and the number of NAs is very low, we will fill in the missing values with the mode and create dummy variables for the levels.

# %%
model_v01_data.loc[:,'sex'] = model_v01_data.sex.fillna(model_v01_data.sex.mode())

# %%
model_v01_data = pd.get_dummies(data = model_v01_data, prefix = 'sex', prefix_sep = ':', columns = ['sex'], drop_first = False, dummy_na = True)

# %%
model_v01_data.head()
# Out:
#   province   age     state  infection_case:contact with patient  \
# 0    Seoul  50.0  released                                    0
# 1    Seoul  30.0  released                                    0
# 2    Seoul  50.0  released                                    1
# 3    Seoul  20.0  released                                    0
# 4    Seoul  20.0  released                                    1
#
#    infection_case:other  infection_case:overseas inflow  infection_case:nan  \
# 0                     0                               1                   0
# 1                     0                               1                   0
# 2                     0                               0                   0
# 3                     0                               1                   0
# 4                     0                               0                   0
#
#    sex:female  sex:male  sex:nan
# 0           0         1        0
# 1           0         1        0
# 2           0         1        0
# 3           0         1        0
# 4           1         0        0

# %% [markdown]
# ##### province

# %%
patients_province = patient_info[~patient_info['province'].isnull()]
print(patients_province.shape)
patients_province.sort_values(['confirmed_date'])
# Out:
# (3326, 18)
#       patient_id  global_num     sex  birth_year  age country  \
# 846   1400000001         1.0  female      1985.0  30s   China
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1065  2000000001         3.0    male      1966.0  50s   Korea
# 1066  2000000002         4.0    male      1964.0  50s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 1720  2000000656         NaN    male      1964.0  50s   Korea
# 1719  2000000655         NaN  female      1998.0  20s   Korea
# 2923  6011000051         NaN  female      1980.0  40s   Korea
# 2924  6011000052         NaN  female      2011.0   0s   Korea
# 2925  6011000053         NaN  female      2001.0  10s   Korea
#
#               province           city disease        infection_case  \
# 846            Incheon            etc     NaN       overseas inflow
# 0                Seoul     Gangseo-gu     NaN       overseas inflow
# 1065       Gyeonggi-do      Goyang-si     NaN       overseas inflow
# 1066       Gyeonggi-do  Pyeongtaek-si     NaN       overseas inflow
# 2                Seoul      Jongno-gu     NaN  contact with patient
# ...                ...            ...     ...                   ...
# 1720       Gyeonggi-do   Namyangju-si     NaN  contact with patient
# 1719       Gyeonggi-do      Yongin-si     NaN       overseas inflow
# 2923  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2924  Gyeongsangbuk-do      Andong-si     NaN                   etc
# 2925  Gyeongsangbuk-do      Andong-si     NaN                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 846               NaN           NaN             NaN         2020-01-19
# 0                 1.0           NaN            75.0         2020-01-22
# 1065              1.0           NaN            16.0                NaN
# 1066              1.0           NaN            95.0                NaN
# 2                 2.0  2.002000e+09            17.0                NaN
# ...               ...           ...             ...                ...
# 1720              NaN  2.000001e+09             NaN                NaN
# 1719              NaN           NaN             NaN                NaN
# 2923              NaN           NaN             NaN                NaN
# 2924              NaN           NaN             NaN                NaN
# 2925              NaN           NaN             NaN         2020-04-15
#
#      confirmed_date released_date deceased_date     state
# 846      2020-01-20    2020-02-06           NaN  released
# 0        2020-01-23    2020-02-05           NaN  released
# 1065     2020-01-26    2020-02-12           NaN  released
# 1066     2020-01-27    2020-02-09           NaN  released
# 2        2020-01-30    2020-02-19           NaN  released
# ...             ...           ...           ...       ...
# 1720     2020-04-19           NaN           NaN  isolated
# 1719     2020-04-19           NaN           NaN  isolated
# 2923            NaN           NaN           NaN  isolated
# 2924            NaN           NaN           NaN  isolated
# 2925            NaN           NaN           NaN  isolated
#
# [3326 rows x 18 columns]

# %%
patients_province.state.value_counts()
# Out:
# released    1637
# isolated    1622
# deceased      67
# Name: state, dtype: int64

# %%
patients_province.province.value_counts()
# Out:
# Gyeongsangbuk-do     1223
# Gyeonggi-do           656
# Seoul                 624
# Chungcheongnam-do     141
# Busan                 129
# Gyeongsangnam-do      115
# Incheon                92
# Daegu                  63
# Sejong                 46
# Chungcheongbuk-do      44
# Ulsan                  42
# Daejeon                39
# Gangwon-do             37
# Gwangju                30
# Jeollabuk-do           17
# Jeollanam-do           15
# Jeju-do                13
# Name: province, dtype: int64

# %% [markdown]
# As we can see, this column has data which encompasses old and current dates, and comprises all possible patient states. As it is a categorical variable, we will fill create dummy variables for the levels.

# %%
model_v01_data = pd.get_dummies(data = model_v01_data, prefix = 'province', prefix_sep = ':', columns = ['province'], drop_first = False, dummy_na = True)

# %%
model_v01_data.head()
# Out:
#     age     state  infection_case:contact with patient  infection_case:other  \
# 0  50.0  released                                    0                     0
# 1  30.0  released                                    0                     0
# 2  50.0  released                                    1                     0
# 3  20.0  released                                    0                     0
# 4  20.0  released                                    1                     0
#
#    infection_case:overseas inflow  infection_case:nan  sex:female  sex:male  \
# 0                               1                   0           0         1
# 1                               1                   0           0         1
# 2                               0                   0           0         1
# 3                               1                   0           0         1
# 4                               0                   0           1         0
#
#    sex:nan  province:Busan  ...  province:Gyeongsangbuk-do  \
# 0        0               0  ...                          0
# 1        0               0  ...                          0
# 2        0               0  ...                          0
# 3        0               0  ...                          0
# 4        0               0  ...                          0
#
#    province:Gyeongsangnam-do  province:Incheon  province:Jeju-do  \
# 0                          0                 0                 0
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 4                          0                 0                 0
#
#    province:Jeollabuk-do  province:Jeollanam-do  province:Sejong  \
# 0                      0                      0                0
# 1                      0                      0                0
# 2                      0                      0                0
# 3                      0                      0                0
# 4                      0                      0                0
#
#    province:Seoul  province:Ulsan  province:nan
# 0               1               0             0
# 1               1               0             0
# 2               1               0             0
# 3               1               0             0
# 4               1               0             0
#
# [5 rows x 27 columns]

# %% [markdown]
# ##### state

# %%
model_v01_data.state.value_counts()
# Out:
# released    1637
# isolated    1622
# deceased      67
# Name: state, dtype: int64

# %% [markdown]
# As we can see, there are three possible states for the patient. As we are aiming at final states, we will only consider the states: released and deceased, removing rows with the other states. We will also encode it as a binary variable (0 for released and 1 for deceased).

# %%
model_v01_data = model_v01_data[model_v01_data['state'].isin(['released','deceased'])]
model_v01_data.loc[:,'state'] = model_v01_data['state'].transform(lambda x: 0 if x == 'released' else 1)

# %%
model_v01_data.head()
# Out:
#     age  state  infection_case:contact with patient  infection_case:other  \
# 0  50.0      0                                    0                     0
# 1  30.0      0                                    0                     0
# 2  50.0      0                                    1                     0
# 3  20.0      0                                    0                     0
# 4  20.0      0                                    1                     0
#
#    infection_case:overseas inflow  infection_case:nan  sex:female  sex:male  \
# 0                               1                   0           0         1
# 1                               1                   0           0         1
# 2                               0                   0           0         1
# 3                               1                   0           0         1
# 4                               0                   0           1         0
#
#    sex:nan  province:Busan  ...  province:Gyeongsangbuk-do  \
# 0        0               0  ...                          0
# 1        0               0  ...                          0
# 2        0               0  ...                          0
# 3        0               0  ...                          0
# 4        0               0  ...                          0
#
#    province:Gyeongsangnam-do  province:Incheon  province:Jeju-do  \
# 0                          0                 0                 0
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 4                          0                 0                 0
#
#    province:Jeollabuk-do  province:Jeollanam-do  province:Sejong  \
# 0                      0                      0                0
# 1                      0                      0                0
# 2                      0                      0                0
# 3                      0                      0                0
# 4                      0                      0                0
#
#    province:Seoul  province:Ulsan  province:nan
# 0               1               0             0
# 1               1               0             0
# 2               1               0             0
# 3               1               0             0
# 4               1               0             0
#
# [5 rows x 27 columns]

# %%
model_v01_data.shape
# Out:
# (1704, 27)

# %%
model_v01_data.state.value_counts()
# Out:
# 0    1637
# 1      67
# Name: state, dtype: int64

# %%
model_v01_data.state.value_counts()[0]/model_v01_data.state.value_counts()[1]
# Out:
# 24.432835820895523

# %% [markdown]
# ### Create Model

# %% [markdown]
# #### Split Original data into Train/Test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(model_v01_data.drop('state', axis=1), model_v01_data['state'], test_size=0.2, random_state=199)

# %% [markdown]
# #### Run Cross-validation using the model pipeline

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

scaler = StandardScaler()
model = LogisticRegression(random_state=199, class_weight={0:1.0,1:24.4},
                                 solver='lbfgs', multi_class='auto')

pipeline = make_pipeline(scaler, model)

kf = KFold(n_splits=10, shuffle=True, random_state=199)
cv_results = cross_val_score(pipeline, # Pipeline
                             x_train, # Feature matrix
                             y_train, # Target vector
                             cv=kf, # Cross-validation technique
                             scoring="accuracy", # Loss function
                             n_jobs=-1) # Use all CPU scores

# %%
cv_results
# Out:
# array([0.87591241, 0.89781022, 0.89781022, 0.88970588, 0.90441176,
#        0.91911765, 0.93382353, 0.91176471, 0.91176471, 0.93382353])

# %% [markdown]
# #### Fit model on whole train data and then predict on test data

# %%
x_train_std = scaler.fit_transform(x_train)
x_test_std = scaler.transform(x_test)
model.fit(x_train_std, y_train)
y_pred = model.predict(x_test_std)

# %%
train_score = model.score(x_train_std, y_train)
print(train_score)
# Out:
# 0.9134262655906089

# %%
test_score = model.score(x_test_std, y_test)
print(test_score)
# Out:
# 0.8944281524926686

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[296,  31],
#        [  5,   9]])

# %% [markdown]
# #### Inspecting Model Coefficients

# %%
model.classes_
# Out:
# array([0, 1])

# %%
coef_dict = {}
for coef, feat in zip(model.coef_[0],list(x_train.columns.values)):
    coef_dict[feat] = coef
{k: v for k, v in sorted(coef_dict.items(), key=lambda item: abs(item[1]), reverse=True)}
# Out:
# {'age': 2.2840649793322547,
#  'infection_case:contact with patient': -1.6738581459699164,
#  'infection_case:other': 1.3086303915997037,
#  'province:Gyeongsangbuk-do': 0.983552788582555,
#  'province:Gyeongsangnam-do': -0.9487130613769071,
#  'province:Daegu': 0.891959934300127,
#  'infection_case:overseas inflow': -0.655998735155795,
#  'province:Chungcheongnam-do': -0.6462783784533284,
#  'province:Gyeonggi-do': 0.6258354467685925,
#  'sex:male': 0.6143922905488394,
#  'province:Chungcheongbuk-do': -0.6100455167224876,
#  'province:Daejeon': -0.6021422694416142,
#  'sex:female': -0.5915066874986133,
#  'province:Gangwon-do': -0.5566139960340694,
#  'province:Incheon': -0.5244987702251156,
#  'province:Sejong': -0.49321973784945944,
#  'infection_case:nan': 0.4925191695072915,
#  'province:Gwangju': -0.32870286848190833,
#  'province:Ulsan': 0.22699355313920963,
#  'sex:nan': -0.20633587060546527,
#  'province:Jeju-do': -0.1696053382349425,
#  'province:Jeollabuk-do': -0.07993563189776154,
#  'province:Seoul': 0.07599288288322988,
#  'province:Jeollanam-do': -0.06943104093778298,
#  'province:Busan': 0.06767414813067482,
#  'province:nan': 0.0}

# %% [markdown]
# #### Top Features (higher effect) overall

# %%
{k: v for k, v in sorted(coef_dict.items(), key=lambda item: abs(item[1]), reverse=True)[:5]}
# Out:
# {'age': 2.2840649793322547,
#  'infection_case:contact with patient': -1.6738581459699164,
#  'infection_case:other': 1.3086303915997037,
#  'province:Gyeongsangbuk-do': 0.983552788582555,
#  'province:Gyeongsangnam-do': -0.9487130613769071}

# %% [markdown]
# - Age (+)
# - Infection Case - Contact with other Patient (-)
# - Infection Case - Other (+)
# - Province Gyeongsangnam-do (-)
# - Province Gyeongsangbuk-do (+)

# %% [markdown]
# #### Top Features (higher effect) for deceased state

# %%
{k: v for k, v in sorted(coef_dict.items(), key=lambda item: item[1], reverse=True)[:5]}
# Out:
# {'age': 2.2840649793322547,
#  'infection_case:other': 1.3086303915997037,
#  'province:Gyeongsangbuk-do': 0.983552788582555,
#  'province:Daegu': 0.891959934300127,
#  'province:Gyeonggi-do': 0.6258354467685925}

# %% [markdown]
# - Age
# - Infection Case (Other)
# - Province Gyeongsangbuk-do
# - Province Daegu
# - sex Male

# %% [markdown]
# #### Top Features (higher effect) for released state

# %%
{k: v for k, v in sorted(coef_dict.items(), key=lambda item: item[1])[:5]}
# Out:
# {'infection_case:contact with patient': -1.6738581459699164,
#  'province:Gyeongsangnam-do': -0.9487130613769071,
#  'infection_case:overseas inflow': -0.655998735155795,
#  'province:Chungcheongnam-do': -0.6462783784533284,
#  'province:Chungcheongbuk-do': -0.6100455167224876}

# %% [markdown]
# - Infection Case (Contact with other Patient)
# - Province Gyeongsangnam-do
# - Infection Case (Overseas Inflow)
# - Province Chungcheongnam-do
# - Province Daejeon

# %% [markdown]
# #### Create Diverging Bars plot with Model Coefficients

# %% [markdown]
# ##### Create dataframe with model coefficients

# %%
def get_feature_pretty_name(feature):
    pretty_feature_base_name = pretty_feature_detailed_name = join_str = ''
    feature_split = feature.split(':')
    pretty_feature_base_name = feature_split[0].replace('_',' ').title()
    
    if (len(feature_split) > 1):
        join_str = ': '
        if (feature_split[1] == 'nan'):
            pretty_feature_detailed_name = 'Missing Value'
        else:
            pretty_feature_detailed_name = feature_split[1].replace('_',' ').title()
    
    return pretty_feature_base_name + join_str + pretty_feature_detailed_name
    
get_feature_pretty_name('sex:male')
# Out:
# 'Sex: Male'

# %%
model_coefs_df = pd.DataFrame(coef_dict.items(), columns=['feature', 'coef']).sort_values('coef', ascending=False)
model_coefs_df['color'] = ['red' if x > 0 else 'green' for x in model_coefs_df['coef']]
model_coefs_df['pretty_feature_name'] = model_coefs_df.feature.apply(get_feature_pretty_name)
model_coefs_df.reset_index(inplace=True)
model_coefs_df
# Out:
#     index                              feature      coef  color  \
# 0       0                                  age  2.284065    red
# 1       2                 infection_case:other  1.308630    red
# 2      16            province:Gyeongsangbuk-do  0.983553    red
# 3      11                       province:Daegu  0.891960    red
# 4      15                 province:Gyeonggi-do  0.625835    red
# 5       6                             sex:male  0.614392    red
# 6       4                   infection_case:nan  0.492519    red
# 7      24                       province:Ulsan  0.226994    red
# 8      23                       province:Seoul  0.075993    red
# 9       8                       province:Busan  0.067674    red
# 10     25                         province:nan  0.000000  green
# 11     21                province:Jeollanam-do -0.069431  green
# 12     20                province:Jeollabuk-do -0.079936  green
# 13     19                     province:Jeju-do -0.169605  green
# 14      7                              sex:nan -0.206336  green
# 15     14                     province:Gwangju -0.328703  green
# 16     22                      province:Sejong -0.493220  green
# 17     18                     province:Incheon -0.524499  green
# 18     13                  province:Gangwon-do -0.556614  green
# 19      5                           sex:female -0.591507  green
# 20     12                     province:Daejeon -0.602142  green
# 21      9           province:Chungcheongbuk-do -0.610046  green
# 22     10           province:Chungcheongnam-do -0.646278  green
# 23      3       infection_case:overseas inflow -0.655999  green
# 24     17            province:Gyeongsangnam-do -0.948713  green
# 25      1  infection_case:contact with patient -1.673858  green
#
#                      pretty_feature_name
# 0                                    Age
# 1                  Infection Case: Other
# 2             Province: Gyeongsangbuk-Do
# 3                        Province: Daegu
# 4                  Province: Gyeonggi-Do
# 5                              Sex: Male
# 6          Infection Case: Missing Value
# 7                        Province: Ulsan
# 8                        Province: Seoul
# 9                        Province: Busan
# 10               Province: Missing Value
# 11                Province: Jeollanam-Do
# 12                Province: Jeollabuk-Do
# 13                     Province: Jeju-Do
# 14                    Sex: Missing Value
# 15                     Province: Gwangju
# 16                      Province: Sejong
# 17                     Province: Incheon
# 18                  Province: Gangwon-Do
# 19                           Sex: Female
# 20                     Province: Daejeon
# 21           Province: Chungcheongbuk-Do
# 22           Province: Chungcheongnam-Do
# 23       Infection Case: Overseas Inflow
# 24            Province: Gyeongsangnam-Do
# 25  Infection Case: Contact With Patient

# %%
# Draw plot
f = plt.figure(figsize=(12,8), dpi= 80)
plt.hlines(y=model_coefs_df.index, xmin=0, xmax=model_coefs_df.coef, 
           color=model_coefs_df.color, alpha=0.4, linewidth=10)

# Decorations
plt.gca().set_xlabel(xlabel='Influence (Coefficient Value)', fontsize=14)
plt.gca().set_ylabel(ylabel='Feature', fontsize=14)
plt.yticks(model_coefs_df.index, model_coefs_df.pretty_feature_name, fontsize=11)
plt.title('Model Feature Influence', fontdict={'size':18})
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %%
f.savefig("../../assets/q2-patient-status-influencers.png", bbox_inches='tight', dpi=600);
